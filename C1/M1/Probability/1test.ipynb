# %%
import pandas as pd
df = pd.read_csv("condProb.csv")
df.head()
df["Recovery"] = df["Recovery (%)"].str.replace("%","").astype(float)
df.drop(columns=df.columns[[2,4,5]], inplace=True)
df["Recovered_Amount"] = (1-df["Recovery"]/100)*df.iloc[:,1]*df.iloc[:,2]
print(sum(df["Recovered_Amount"]))

# df.columns[0]              # gives column name at position 0                                                                                                                                          
# list_index = [0, 1, 2]                                                                                                                                                                                
# df.columns[list_index]     # gives Index of column names at those positions
# Out:
# 493.39131440620133
# 'Customer No.'
