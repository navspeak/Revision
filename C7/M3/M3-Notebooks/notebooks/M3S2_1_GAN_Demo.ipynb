# %% [markdown]
# # Introduction
# In this demonstration, we will implement a generative adversarial network (GAN) to generate random new realistic images of clothing apparels by training it on the fashion-MNIST dataset from `keras`. The objective of this demonstration is to motivate the importance of latent spaces and how they can be used to generate new images.

# %% [markdown]
# ## Setup
# Let us import the necessary packages and methods for this demonstration:
# - Working with numeric structures: `numpy`
# - Working with images: `matplotlib.pyplot`
# - Working with artificial neural networks: `tensorflow`, `keras`

# %%
# Load necessary methods and packages
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
# Let us load the fashion-MNIST dataset and study the images that we are working with.

# %%
# Import the 'fashion_mnist' data package from 'keras'
from keras.datasets import fashion_mnist

# Load the data
(X_train, _), (X_test, _) = fashion_mnist.load_data()

# Undo the train-test split
X = np.concatenate([X_train, X_test], axis = 0)

# Normalize the pixel gray levels
X = np.expand_dims(X, -1).astype('float32') / 255

# %% [markdown]
# GANs are used for random image generation and hence follow a different training regime. Because of this, we have the following considerations:
# - We do not need the $y$ values that are generally used for classification
# - We do not need a train-test split

# %%
# Sample a few fashion MNIST images from the data and view the images
indices = np.random.randint(0, X.shape[0], size = 25)

images = X[indices]

plt.figure(figsize = (5, 5))

for i in np.arange(0, len(indices), 1):
    plt.subplot(5, 5, i + 1)
    image = images[i]
    plt.imshow(image, cmap = 'gray')
    plt.axis('off')

# %% [markdown]
# You can see that the fashion-MNIST data are grayscale images of size 28x28 of various clothing apparels such as shoes, shirts, and so on.

# %%
# Study the shape of the data
print('Data shape: ', X.shape) # (70000, 28, 28, 1) --- 70000 images, each 28x28 pixels
# Out:
# Data shape:  (70000, 28, 28, 1)

# %% [markdown]
# # Part 1 - Building the GAN
# In this section, we will construct the components of the GAN but we will not combine them into a single model. This is because we need to discard the discriminator at the end anyway. Note that the GAN is primarily comprised of the generator and the discriminator during training and only the generator during inference.

# %% [markdown]
# ### Generator
# The generator (G) is designed to map the latent space vector $z$ to the image space.
#
# Let's define a function to build the generator. The generator is essentially a combination of a fully connected layer followed by transpose convolutional layers that produce images at the end.

# %%
# Define the generator
def build_generator(latent_dim = 1):
    G = keras.models.Sequential([layers.Dense(28 * 28 * 256, use_bias = False, input_shape = (latent_dim,)),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Reshape((28, 28, 256)),
                                 layers.Conv2DTranspose(filters = 128, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 64, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 32, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.BatchNormalization(),
                                 layers.LeakyReLU(),
                                 layers.Conv2DTranspose(filters = 1, kernel_size = 3, strides = 1, use_bias = False, padding = 'same')])

    return G

# %% [markdown]
# ### Discriminator
# The discriminator (D) is designed to be able to tell the difference between a real image and an image that is generated by the generator.
#
# Let's define a function to build the discriminator. The discriminator is a combination of convolutioanl layers and a fully connected at the end to classify incoming images.

# %%
# Define the discriminator
def build_discriminator():
    D = keras.models.Sequential([layers.Conv2D(filters = 32, kernel_size = 3, strides = 1, use_bias = False, padding = 'same', input_shape = (28, 28, 1)),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Conv2D(filters = 64, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Conv2D(filters = 128, kernel_size = 3, strides = 1, use_bias = False, padding = 'same'),
                                 layers.LeakyReLU(),
                                 layers.Dropout(rate = 0.3),
                                 layers.Flatten(),
                                 layers.Dense(units = 1, use_bias = False)])

    return D

# %% [markdown]
# Now that the generator and the discriminator have been defined, we can instantiate them as components of the GAN.

# %%
# Set a latent vector size
latent_dim = 4

# %% [markdown]
# GANs also use random vectors from a latent space to generate new images.

# %%
# Create generator
generator = build_generator(latent_dim = latent_dim)

# Print the summary of the model
generator.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 200704)         │       802,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200704)         │       802,816 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 28, 28, 128)    │       294,912 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 28, 28, 64)     │        73,728 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 28, 28, 32)     │        18,432 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 28, 28, 1)      │           288 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,993,888 (7.61 MB)
#  Trainable params: 1,592,032 (6.07 MB)
#  Non-trainable params: 401,856 (1.53 MB)

# %%
# Create discriminator
discriminator = build_discriminator()

# Print the summary of the model
discriminator.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │       100,352 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 192,800 (753.12 KB)
#  Trainable params: 192,800 (753.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Part 2 - Training the Network
# In this section, we will define loss functions for the GAN and train it.

# %%
# Define loss functions
cross_entropy = keras.losses.BinaryCrossentropy(from_logits = True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss

    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
# Define the optimizers
generator_optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0005)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0005)

# %%
# Set a batch size and a number of epochs
batch_size = 64
n_epochs = 5

# %%
# Define the training step
@tf.function
def train_step(images = None, batch_size = 1, latent_dim = 1):
    noise = tf.random.normal([batch_size, latent_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as dis_tape:
        generated_images = generator(noise, training = True)

        real_output = discriminator(images, training = True)
        fake_output = discriminator(generated_images, training = True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = dis_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
# Run the training loop
n_batches = X.shape[0] // batch_size
loss_comps = n_epochs * n_batches
i = 0
for epoch in range(n_epochs):
    for batch in range(n_batches):
        i = i + 1
        print('Parameter updates using loss computation number {} out of {} computations...'.format(i, loss_comps))
        batch_images = X[batch * batch_size : (batch + 1) * batch_size]
        train_step(images = batch_images, batch_size = batch_size, latent_dim = latent_dim)
# Out:
# Parameter updates using loss computation number 1 out of 5465 computations...
# Parameter updates using loss computation number 2 out of 5465 computations...
# Parameter updates using loss computation number 3 out of 5465 computations...
# Parameter updates using loss computation number 4 out of 5465 computations...
# Parameter updates using loss computation number 5 out of 5465 computations...
# Parameter updates using loss computation number 6 out of 5465 computations...
# Parameter updates using loss computation number 7 out of 5465 computations...
# Parameter updates using loss computation number 8 out of 5465 computations...
# Parameter updates using loss computation number 9 out of 5465 computations...
# Parameter updates using loss computation number 10 out of 5465 computations...
# Parameter updates using loss computation number 11 out of 5465 computations...
# Parameter updates using loss computation number 12 out of 5465 computations...
# Parameter updates using loss computation number 13 out of 5465 computations...
# Parameter updates using loss computation number 14 out of 5465 computations...
# Parameter updates using loss computation number 15 out of 5465 computations...
# Parameter updates using loss computation number 16 out of 5465 computations...
# Parameter updates using loss computation number 17 out of 5465 computations...
# Parameter updates using loss computation number 18 out of 5465 computations...
# Parameter updates using loss computation number 19 out of 5465 computations...
# Parameter updates using loss computation number 20 out of 5465 computations...
# Parameter updates using loss computation number 21 out of 5465 computations...
# Parameter updates using loss computation number 22 out of 5465 computations...
# Parameter updates using loss computation number 23 out of 5465 computations...
# Parameter updates using loss computation number 24 out of 5465 computations...
# Parameter updates using loss computation number 25 out of 5465 computations...
# Parameter updates using loss computation number 26 out of 5465 computations...
# Parameter updates using loss computation number 27 out of 5465 computations...
# Parameter updates using loss computation number 28 out of 5465 computations...
# Parameter updates using loss computation number 29 out of 5465 computations...
# Parameter updates using loss computation number 30 out of 5465 computations...
# Parameter updates using loss computation number 31 out of 5465 computations...
# Parameter updates using loss computation number 32 out of 5465 computations...
# Parameter updates using loss computation number 33 out of 5465 computations...
# Parameter updates using loss computation number 34 out of 5465 computations...
# Parameter updates using loss computation number 35 out of 5465 computations...
# Parameter updates using loss computation number 36 out of 5465 computations...
# Parameter updates using loss computation number 37 out of 5465 computations...
# Parameter updates using loss computation number 38 out of 5465 computations...
# Parameter updates using loss computation number 39 out of 5465 computations...
# Parameter updates using loss computation number 40 out of 5465 computations...
# Parameter updates using loss computation number 41 out of 5465 computations...
# Parameter updates using loss computation number 42 out of 5465 computations...
# Parameter updates using loss computation number 43 out of 5465 computations...
# Parameter updates using loss computation number 44 out of 5465 computations...
# Parameter updates using loss computation number 45 out of 5465 computations...
# Parameter updates using loss computation number 46 out of 5465 computations...
# Parameter updates using loss computation number 47 out of 5465 computations...
# Parameter updates using loss computation number 48 out of 5465 computations...
# Parameter updates using loss computation number 49 out of 5465 computations...
# Parameter updates using loss computation number 50 out of 5465 computations...
# Parameter updates using loss computation number 51 out of 5465 computations...
# Parameter updates using loss computation number 52 out of 5465 computations...
# Parameter updates using loss computation number 53 out of 5465 computations...
# Parameter updates using loss computation number 54 out of 5465 computations...
# Parameter updates using loss computation number 55 out of 5465 computations...
# Parameter updates using loss computation number 56 out of 5465 computations...
# Parameter updates using loss computation number 57 out of 5465 computations...
# Parameter updates using loss computation number 58 out of 5465 computations...
# Parameter updates using loss computation number 59 out of 5465 computations...
# Parameter updates using loss computation number 60 out of 5465 computations...
# Parameter updates using loss computation number 61 out of 5465 computations...
# Parameter updates using loss computation number 62 out of 5465 computations...
# Parameter updates using loss computation number 63 out of 5465 computations...
# Parameter updates using loss computation number 64 out of 5465 computations...
# Parameter updates using loss computation number 65 out of 5465 computations...
# Parameter updates using loss computation number 66 out of 5465 computations...
# Parameter updates using loss computation number 67 out of 5465 computations...
# Parameter updates using loss computation number 68 out of 5465 computations...
# Parameter updates using loss computation number 69 out of 5465 computations...
# Parameter updates using loss computation number 70 out of 5465 computations...
# Parameter updates using loss computation number 71 out of 5465 computations...
# Parameter updates using loss computation number 72 out of 5465 computations...
# Parameter updates using loss computation number 73 out of 5465 computations...
# Parameter updates using loss computation number 74 out of 5465 computations...
# Parameter updates using loss computation number 75 out of 5465 computations...
# Parameter updates using loss computation number 76 out of 5465 computations...
# Parameter updates using loss computation number 77 out of 5465 computations...
# Parameter updates using loss computation number 78 out of 5465 computations...
# Parameter updates using loss computation number 79 out of 5465 computations...
# Parameter updates using loss computation number 80 out of 5465 computations...
# Parameter updates using loss computation number 81 out of 5465 computations...
# Parameter updates using loss computation number 82 out of 5465 computations...
# Parameter updates using loss computation number 83 out of 5465 computations...
# Parameter updates using loss computation number 84 out of 5465 computations...
# Parameter updates using loss computation number 85 out of 5465 computations...
# Parameter updates using loss computation number 86 out of 5465 computations...
# Parameter updates using loss computation number 87 out of 5465 computations...
# Parameter updates using loss computation number 88 out of 5465 computations...
# Parameter updates using loss computation number 89 out of 5465 computations...
# Parameter updates using loss computation number 90 out of 5465 computations...
# Parameter updates using loss computation number 91 out of 5465 computations...
# Parameter updates using loss computation number 92 out of 5465 computations...
# Parameter updates using loss computation number 93 out of 5465 computations...
# Parameter updates using loss computation number 94 out of 5465 computations...
# Parameter updates using loss computation number 95 out of 5465 computations...
# Parameter updates using loss computation number 96 out of 5465 computations...
# Parameter updates using loss computation number 97 out of 5465 computations...
# Parameter updates using loss computation number 98 out of 5465 computations...
# Parameter updates using loss computation number 99 out of 5465 computations...
# Parameter updates using loss computation number 100 out of 5465 computations...
# Parameter updates using loss computation number 101 out of 5465 computations...
# Parameter updates using loss computation number 102 out of 5465 computations...
# Parameter updates using loss computation number 103 out of 5465 computations...
# Parameter updates using loss computation number 104 out of 5465 computations...
# Parameter updates using loss computation number 105 out of 5465 computations...
# Parameter updates using loss computation number 106 out of 5465 computations...
# Parameter updates using loss computation number 107 out of 5465 computations...
# Parameter updates using loss computation number 108 out of 5465 computations...
# Parameter updates using loss computation number 109 out of 5465 computations...
# Parameter updates using loss computation number 110 out of 5465 computations...
# Parameter updates using loss computation number 111 out of 5465 computations...
# Parameter updates using loss computation number 112 out of 5465 computations...
# Parameter updates using loss computation number 113 out of 5465 computations...
# Parameter updates using loss computation number 114 out of 5465 computations...
# Parameter updates using loss computation number 115 out of 5465 computations...
# Parameter updates using loss computation number 116 out of 5465 computations...
# Parameter updates using loss computation number 117 out of 5465 computations...
# Parameter updates using loss computation number 118 out of 5465 computations...
# Parameter updates using loss computation number 119 out of 5465 computations...
# Parameter updates using loss computation number 120 out of 5465 computations...
# Parameter updates using loss computation number 121 out of 5465 computations...
# Parameter updates using loss computation number 122 out of 5465 computations...
# Parameter updates using loss computation number 123 out of 5465 computations...
# Parameter updates using loss computation number 124 out of 5465 computations...
# Parameter updates using loss computation number 125 out of 5465 computations...
# Parameter updates using loss computation number 126 out of 5465 computations...
# Parameter updates using loss computation number 127 out of 5465 computations...
# Parameter updates using loss computation number 128 out of 5465 computations...
# Parameter updates using loss computation number 129 out of 5465 computations...
# Parameter updates using loss computation number 130 out of 5465 computations...
# Parameter updates using loss computation number 131 out of 5465 computations...
# Parameter updates using loss computation number 132 out of 5465 computations...
# Parameter updates using loss computation number 133 out of 5465 computations...
# Parameter updates using loss computation number 134 out of 5465 computations...
# Parameter updates using loss computation number 135 out of 5465 computations...
# Parameter updates using loss computation number 136 out of 5465 computations...
# Parameter updates using loss computation number 137 out of 5465 computations...
# Parameter updates using loss computation number 138 out of 5465 computations...
# Parameter updates using loss computation number 139 out of 5465 computations...
# Parameter updates using loss computation number 140 out of 5465 computations...
# Parameter updates using loss computation number 141 out of 5465 computations...
# Parameter updates using loss computation number 142 out of 5465 computations...
# Parameter updates using loss computation number 143 out of 5465 computations...
# Parameter updates using loss computation number 144 out of 5465 computations...
# Parameter updates using loss computation number 145 out of 5465 computations...
# Parameter updates using loss computation number 146 out of 5465 computations...
# Parameter updates using loss computation number 147 out of 5465 computations...
# Parameter updates using loss computation number 148 out of 5465 computations...
# Parameter updates using loss computation number 149 out of 5465 computations...
# Parameter updates using loss computation number 150 out of 5465 computations...
# Parameter updates using loss computation number 151 out of 5465 computations...
# Parameter updates using loss computation number 152 out of 5465 computations...
# Parameter updates using loss computation number 153 out of 5465 computations...
# Parameter updates using loss computation number 154 out of 5465 computations...
# Parameter updates using loss computation number 155 out of 5465 computations...
# Parameter updates using loss computation number 156 out of 5465 computations...
# Parameter updates using loss computation number 157 out of 5465 computations...
# Parameter updates using loss computation number 158 out of 5465 computations...
# Parameter updates using loss computation number 159 out of 5465 computations...
# Parameter updates using loss computation number 160 out of 5465 computations...
# Parameter updates using loss computation number 161 out of 5465 computations...
# Parameter updates using loss computation number 162 out of 5465 computations...
# Parameter updates using loss computation number 163 out of 5465 computations...
# Parameter updates using loss computation number 164 out of 5465 computations...
# Parameter updates using loss computation number 165 out of 5465 computations...
# Parameter updates using loss computation number 166 out of 5465 computations...
# Parameter updates using loss computation number 167 out of 5465 computations...
# Parameter updates using loss computation number 168 out of 5465 computations...
# Parameter updates using loss computation number 169 out of 5465 computations...
# Parameter updates using loss computation number 170 out of 5465 computations...
# Parameter updates using loss computation number 171 out of 5465 computations...
# Parameter updates using loss computation number 172 out of 5465 computations...
# Parameter updates using loss computation number 173 out of 5465 computations...
# Parameter updates using loss computation number 174 out of 5465 computations...
# Parameter updates using loss computation number 175 out of 5465 computations...
# Parameter updates using loss computation number 176 out of 5465 computations...
# Parameter updates using loss computation number 177 out of 5465 computations...
# Parameter updates using loss computation number 178 out of 5465 computations...
# Parameter updates using loss computation number 179 out of 5465 computations...
# Parameter updates using loss computation number 180 out of 5465 computations...
# Parameter updates using loss computation number 181 out of 5465 computations...
# Parameter updates using loss computation number 182 out of 5465 computations...
# Parameter updates using loss computation number 183 out of 5465 computations...
# Parameter updates using loss computation number 184 out of 5465 computations...
# Parameter updates using loss computation number 185 out of 5465 computations...
# Parameter updates using loss computation number 186 out of 5465 computations...
# Parameter updates using loss computation number 187 out of 5465 computations...
# Parameter updates using loss computation number 188 out of 5465 computations...
# Parameter updates using loss computation number 189 out of 5465 computations...
# Parameter updates using loss computation number 190 out of 5465 computations...
# Parameter updates using loss computation number 191 out of 5465 computations...
# Parameter updates using loss computation number 192 out of 5465 computations...
# Parameter updates using loss computation number 193 out of 5465 computations...
# Parameter updates using loss computation number 194 out of 5465 computations...
# Parameter updates using loss computation number 195 out of 5465 computations...
# Parameter updates using loss computation number 196 out of 5465 computations...
# Parameter updates using loss computation number 197 out of 5465 computations...
# Parameter updates using loss computation number 198 out of 5465 computations...
# Parameter updates using loss computation number 199 out of 5465 computations...
# Parameter updates using loss computation number 200 out of 5465 computations...
# Parameter updates using loss computation number 201 out of 5465 computations...
# Parameter updates using loss computation number 202 out of 5465 computations...
# Parameter updates using loss computation number 203 out of 5465 computations...
# Parameter updates using loss computation number 204 out of 5465 computations...
# Parameter updates using loss computation number 205 out of 5465 computations...
# Parameter updates using loss computation number 206 out of 5465 computations...
# Parameter updates using loss computation number 207 out of 5465 computations...
# Parameter updates using loss computation number 208 out of 5465 computations...
# Parameter updates using loss computation number 209 out of 5465 computations...
# Parameter updates using loss computation number 210 out of 5465 computations...
# Parameter updates using loss computation number 211 out of 5465 computations...
# Parameter updates using loss computation number 212 out of 5465 computations...
# Parameter updates using loss computation number 213 out of 5465 computations...
# Parameter updates using loss computation number 214 out of 5465 computations...
# Parameter updates using loss computation number 215 out of 5465 computations...
# Parameter updates using loss computation number 216 out of 5465 computations...
# Parameter updates using loss computation number 217 out of 5465 computations...
# Parameter updates using loss computation number 218 out of 5465 computations...
# Parameter updates using loss computation number 219 out of 5465 computations...
# Parameter updates using loss computation number 220 out of 5465 computations...
# Parameter updates using loss computation number 221 out of 5465 computations...
# Parameter updates using loss computation number 222 out of 5465 computations...
# Parameter updates using loss computation number 223 out of 5465 computations...
# Parameter updates using loss computation number 224 out of 5465 computations...
# Parameter updates using loss computation number 225 out of 5465 computations...
# Parameter updates using loss computation number 226 out of 5465 computations...
# Parameter updates using loss computation number 227 out of 5465 computations...
# Parameter updates using loss computation number 228 out of 5465 computations...
# Parameter updates using loss computation number 229 out of 5465 computations...
# Parameter updates using loss computation number 230 out of 5465 computations...
# Parameter updates using loss computation number 231 out of 5465 computations...
# Parameter updates using loss computation number 232 out of 5465 computations...
# Parameter updates using loss computation number 233 out of 5465 computations...
# Parameter updates using loss computation number 234 out of 5465 computations...
# Parameter updates using loss computation number 235 out of 5465 computations...
# Parameter updates using loss computation number 236 out of 5465 computations...
# Parameter updates using loss computation number 237 out of 5465 computations...
# Parameter updates using loss computation number 238 out of 5465 computations...
# Parameter updates using loss computation number 239 out of 5465 computations...
# Parameter updates using loss computation number 240 out of 5465 computations...
# Parameter updates using loss computation number 241 out of 5465 computations...
# Parameter updates using loss computation number 242 out of 5465 computations...
# Parameter updates using loss computation number 243 out of 5465 computations...
# Parameter updates using loss computation number 244 out of 5465 computations...
# Parameter updates using loss computation number 245 out of 5465 computations...
# Parameter updates using loss computation number 246 out of 5465 computations...
# Parameter updates using loss computation number 247 out of 5465 computations...
# Parameter updates using loss computation number 248 out of 5465 computations...
# Parameter updates using loss computation number 249 out of 5465 computations...
# Parameter updates using loss computation number 250 out of 5465 computations...
# Parameter updates using loss computation number 251 out of 5465 computations...
# Parameter updates using loss computation number 252 out of 5465 computations...
# Parameter updates using loss computation number 253 out of 5465 computations...
# Parameter updates using loss computation number 254 out of 5465 computations...
# Parameter updates using loss computation number 255 out of 5465 computations...
# Parameter updates using loss computation number 256 out of 5465 computations...
# Parameter updates using loss computation number 257 out of 5465 computations...
# Parameter updates using loss computation number 258 out of 5465 computations...
# Parameter updates using loss computation number 259 out of 5465 computations...
# Parameter updates using loss computation number 260 out of 5465 computations...
# Parameter updates using loss computation number 261 out of 5465 computations...
# Parameter updates using loss computation number 262 out of 5465 computations...
# Parameter updates using loss computation number 263 out of 5465 computations...
# Parameter updates using loss computation number 264 out of 5465 computations...
# Parameter updates using loss computation number 265 out of 5465 computations...
# Parameter updates using loss computation number 266 out of 5465 computations...
# Parameter updates using loss computation number 267 out of 5465 computations...
# Parameter updates using loss computation number 268 out of 5465 computations...
# Parameter updates using loss computation number 269 out of 5465 computations...
# Parameter updates using loss computation number 270 out of 5465 computations...
# Parameter updates using loss computation number 271 out of 5465 computations...
# Parameter updates using loss computation number 272 out of 5465 computations...
# Parameter updates using loss computation number 273 out of 5465 computations...
# Parameter updates using loss computation number 274 out of 5465 computations...
# Parameter updates using loss computation number 275 out of 5465 computations...
# Parameter updates using loss computation number 276 out of 5465 computations...
# Parameter updates using loss computation number 277 out of 5465 computations...
# Parameter updates using loss computation number 278 out of 5465 computations...
# Parameter updates using loss computation number 279 out of 5465 computations...
# Parameter updates using loss computation number 280 out of 5465 computations...
# Parameter updates using loss computation number 281 out of 5465 computations...
# Parameter updates using loss computation number 282 out of 5465 computations...
# Parameter updates using loss computation number 283 out of 5465 computations...
# Parameter updates using loss computation number 284 out of 5465 computations...
# Parameter updates using loss computation number 285 out of 5465 computations...
# Parameter updates using loss computation number 286 out of 5465 computations...
# Parameter updates using loss computation number 287 out of 5465 computations...
# Parameter updates using loss computation number 288 out of 5465 computations...
# Parameter updates using loss computation number 289 out of 5465 computations...
# Parameter updates using loss computation number 290 out of 5465 computations...
# Parameter updates using loss computation number 291 out of 5465 computations...
# Parameter updates using loss computation number 292 out of 5465 computations...
# Parameter updates using loss computation number 293 out of 5465 computations...
# Parameter updates using loss computation number 294 out of 5465 computations...
# Parameter updates using loss computation number 295 out of 5465 computations...
# Parameter updates using loss computation number 296 out of 5465 computations...
# Parameter updates using loss computation number 297 out of 5465 computations...
# Parameter updates using loss computation number 298 out of 5465 computations...
# Parameter updates using loss computation number 299 out of 5465 computations...
# Parameter updates using loss computation number 300 out of 5465 computations...
# Parameter updates using loss computation number 301 out of 5465 computations...
# Parameter updates using loss computation number 302 out of 5465 computations...
# Parameter updates using loss computation number 303 out of 5465 computations...
# Parameter updates using loss computation number 304 out of 5465 computations...
# Parameter updates using loss computation number 305 out of 5465 computations...
# Parameter updates using loss computation number 306 out of 5465 computations...
# Parameter updates using loss computation number 307 out of 5465 computations...
# Parameter updates using loss computation number 308 out of 5465 computations...
# Parameter updates using loss computation number 309 out of 5465 computations...
# Parameter updates using loss computation number 310 out of 5465 computations...
# Parameter updates using loss computation number 311 out of 5465 computations...
# Parameter updates using loss computation number 312 out of 5465 computations...
# Parameter updates using loss computation number 313 out of 5465 computations...
# Parameter updates using loss computation number 314 out of 5465 computations...
# Parameter updates using loss computation number 315 out of 5465 computations...
# Parameter updates using loss computation number 316 out of 5465 computations...
# Parameter updates using loss computation number 317 out of 5465 computations...
# Parameter updates using loss computation number 318 out of 5465 computations...
# Parameter updates using loss computation number 319 out of 5465 computations...
# Parameter updates using loss computation number 320 out of 5465 computations...
# Parameter updates using loss computation number 321 out of 5465 computations...
# Parameter updates using loss computation number 322 out of 5465 computations...
# Parameter updates using loss computation number 323 out of 5465 computations...
# Parameter updates using loss computation number 324 out of 5465 computations...
# Parameter updates using loss computation number 325 out of 5465 computations...
# Parameter updates using loss computation number 326 out of 5465 computations...
# Parameter updates using loss computation number 327 out of 5465 computations...
# Parameter updates using loss computation number 328 out of 5465 computations...
# Parameter updates using loss computation number 329 out of 5465 computations...
# Parameter updates using loss computation number 330 out of 5465 computations...
# Parameter updates using loss computation number 331 out of 5465 computations...
# Parameter updates using loss computation number 332 out of 5465 computations...
# Parameter updates using loss computation number 333 out of 5465 computations...
# Parameter updates using loss computation number 334 out of 5465 computations...
# Parameter updates using loss computation number 335 out of 5465 computations...
# Parameter updates using loss computation number 336 out of 5465 computations...
# Parameter updates using loss computation number 337 out of 5465 computations...
# Parameter updates using loss computation number 338 out of 5465 computations...
# Parameter updates using loss computation number 339 out of 5465 computations...
# Parameter updates using loss computation number 340 out of 5465 computations...
# Parameter updates using loss computation number 341 out of 5465 computations...
# Parameter updates using loss computation number 342 out of 5465 computations...
# Parameter updates using loss computation number 343 out of 5465 computations...
# Parameter updates using loss computation number 344 out of 5465 computations...
# Parameter updates using loss computation number 345 out of 5465 computations...
# Parameter updates using loss computation number 346 out of 5465 computations...
# Parameter updates using loss computation number 347 out of 5465 computations...
# Parameter updates using loss computation number 348 out of 5465 computations...
# Parameter updates using loss computation number 349 out of 5465 computations...
# Parameter updates using loss computation number 350 out of 5465 computations...
# Parameter updates using loss computation number 351 out of 5465 computations...
# Parameter updates using loss computation number 352 out of 5465 computations...
# Parameter updates using loss computation number 353 out of 5465 computations...
# Parameter updates using loss computation number 354 out of 5465 computations...
# Parameter updates using loss computation number 355 out of 5465 computations...
# Parameter updates using loss computation number 356 out of 5465 computations...
# Parameter updates using loss computation number 357 out of 5465 computations...
# Parameter updates using loss computation number 358 out of 5465 computations...
# Parameter updates using loss computation number 359 out of 5465 computations...
# Parameter updates using loss computation number 360 out of 5465 computations...
# Parameter updates using loss computation number 361 out of 5465 computations...
# Parameter updates using loss computation number 362 out of 5465 computations...
# Parameter updates using loss computation number 363 out of 5465 computations...
# Parameter updates using loss computation number 364 out of 5465 computations...
# Parameter updates using loss computation number 365 out of 5465 computations...
# Parameter updates using loss computation number 366 out of 5465 computations...
# Parameter updates using loss computation number 367 out of 5465 computations...
# Parameter updates using loss computation number 368 out of 5465 computations...
# Parameter updates using loss computation number 369 out of 5465 computations...
# Parameter updates using loss computation number 370 out of 5465 computations...
# Parameter updates using loss computation number 371 out of 5465 computations...
# Parameter updates using loss computation number 372 out of 5465 computations...
# Parameter updates using loss computation number 373 out of 5465 computations...
# Parameter updates using loss computation number 374 out of 5465 computations...
# Parameter updates using loss computation number 375 out of 5465 computations...
# Parameter updates using loss computation number 376 out of 5465 computations...
# Parameter updates using loss computation number 377 out of 5465 computations...
# Parameter updates using loss computation number 378 out of 5465 computations...
# Parameter updates using loss computation number 379 out of 5465 computations...
# Parameter updates using loss computation number 380 out of 5465 computations...
# Parameter updates using loss computation number 381 out of 5465 computations...
# Parameter updates using loss computation number 382 out of 5465 computations...
# Parameter updates using loss computation number 383 out of 5465 computations...
# Parameter updates using loss computation number 384 out of 5465 computations...
# Parameter updates using loss computation number 385 out of 5465 computations...
# Parameter updates using loss computation number 386 out of 5465 computations...
# Parameter updates using loss computation number 387 out of 5465 computations...
# Parameter updates using loss computation number 388 out of 5465 computations...
# Parameter updates using loss computation number 389 out of 5465 computations...
# Parameter updates using loss computation number 390 out of 5465 computations...
# Parameter updates using loss computation number 391 out of 5465 computations...
# Parameter updates using loss computation number 392 out of 5465 computations...
# Parameter updates using loss computation number 393 out of 5465 computations...
# Parameter updates using loss computation number 394 out of 5465 computations...
# Parameter updates using loss computation number 395 out of 5465 computations...
# Parameter updates using loss computation number 396 out of 5465 computations...
# Parameter updates using loss computation number 397 out of 5465 computations...
# Parameter updates using loss computation number 398 out of 5465 computations...
# Parameter updates using loss computation number 399 out of 5465 computations...
# Parameter updates using loss computation number 400 out of 5465 computations...
# Parameter updates using loss computation number 401 out of 5465 computations...
# Parameter updates using loss computation number 402 out of 5465 computations...
# Parameter updates using loss computation number 403 out of 5465 computations...
# Parameter updates using loss computation number 404 out of 5465 computations...
# Parameter updates using loss computation number 405 out of 5465 computations...
# Parameter updates using loss computation number 406 out of 5465 computations...
# Parameter updates using loss computation number 407 out of 5465 computations...
# Parameter updates using loss computation number 408 out of 5465 computations...
# Parameter updates using loss computation number 409 out of 5465 computations...
# Parameter updates using loss computation number 410 out of 5465 computations...
# Parameter updates using loss computation number 411 out of 5465 computations...
# Parameter updates using loss computation number 412 out of 5465 computations...
# Parameter updates using loss computation number 413 out of 5465 computations...
# Parameter updates using loss computation number 414 out of 5465 computations...
# Parameter updates using loss computation number 415 out of 5465 computations...
# Parameter updates using loss computation number 416 out of 5465 computations...
# Parameter updates using loss computation number 417 out of 5465 computations...
# Parameter updates using loss computation number 418 out of 5465 computations...
# Parameter updates using loss computation number 419 out of 5465 computations...
# Parameter updates using loss computation number 420 out of 5465 computations...
# Parameter updates using loss computation number 421 out of 5465 computations...
# Parameter updates using loss computation number 422 out of 5465 computations...
# Parameter updates using loss computation number 423 out of 5465 computations...
# Parameter updates using loss computation number 424 out of 5465 computations...
# Parameter updates using loss computation number 425 out of 5465 computations...
# Parameter updates using loss computation number 426 out of 5465 computations...
# Parameter updates using loss computation number 427 out of 5465 computations...
# Parameter updates using loss computation number 428 out of 5465 computations...
# Parameter updates using loss computation number 429 out of 5465 computations...
# Parameter updates using loss computation number 430 out of 5465 computations...
# Parameter updates using loss computation number 431 out of 5465 computations...
# Parameter updates using loss computation number 432 out of 5465 computations...
# Parameter updates using loss computation number 433 out of 5465 computations...
# Parameter updates using loss computation number 434 out of 5465 computations...
# Parameter updates using loss computation number 435 out of 5465 computations...
# Parameter updates using loss computation number 436 out of 5465 computations...
# Parameter updates using loss computation number 437 out of 5465 computations...
# Parameter updates using loss computation number 438 out of 5465 computations...
# Parameter updates using loss computation number 439 out of 5465 computations...
# Parameter updates using loss computation number 440 out of 5465 computations...
# Parameter updates using loss computation number 441 out of 5465 computations...
# Parameter updates using loss computation number 442 out of 5465 computations...
# Parameter updates using loss computation number 443 out of 5465 computations...
# Parameter updates using loss computation number 444 out of 5465 computations...
# Parameter updates using loss computation number 445 out of 5465 computations...
# Parameter updates using loss computation number 446 out of 5465 computations...
# Parameter updates using loss computation number 447 out of 5465 computations...
# Parameter updates using loss computation number 448 out of 5465 computations...
# Parameter updates using loss computation number 449 out of 5465 computations...
# Parameter updates using loss computation number 450 out of 5465 computations...
# Parameter updates using loss computation number 451 out of 5465 computations...
# Parameter updates using loss computation number 452 out of 5465 computations...
# Parameter updates using loss computation number 453 out of 5465 computations...
# Parameter updates using loss computation number 454 out of 5465 computations...
# Parameter updates using loss computation number 455 out of 5465 computations...
# Parameter updates using loss computation number 456 out of 5465 computations...
# Parameter updates using loss computation number 457 out of 5465 computations...
# Parameter updates using loss computation number 458 out of 5465 computations...
# Parameter updates using loss computation number 459 out of 5465 computations...
# Parameter updates using loss computation number 460 out of 5465 computations...
# Parameter updates using loss computation number 461 out of 5465 computations...
# Parameter updates using loss computation number 462 out of 5465 computations...
# Parameter updates using loss computation number 463 out of 5465 computations...
# Parameter updates using loss computation number 464 out of 5465 computations...
# Parameter updates using loss computation number 465 out of 5465 computations...
# Parameter updates using loss computation number 466 out of 5465 computations...
# Parameter updates using loss computation number 467 out of 5465 computations...
# Parameter updates using loss computation number 468 out of 5465 computations...
# Parameter updates using loss computation number 469 out of 5465 computations...
# Parameter updates using loss computation number 470 out of 5465 computations...
# Parameter updates using loss computation number 471 out of 5465 computations...
# Parameter updates using loss computation number 472 out of 5465 computations...
# Parameter updates using loss computation number 473 out of 5465 computations...
# Parameter updates using loss computation number 474 out of 5465 computations...
# Parameter updates using loss computation number 475 out of 5465 computations...
# Parameter updates using loss computation number 476 out of 5465 computations...
# Parameter updates using loss computation number 477 out of 5465 computations...
# Parameter updates using loss computation number 478 out of 5465 computations...
# Parameter updates using loss computation number 479 out of 5465 computations...
# Parameter updates using loss computation number 480 out of 5465 computations...
# Parameter updates using loss computation number 481 out of 5465 computations...
# Parameter updates using loss computation number 482 out of 5465 computations...
# Parameter updates using loss computation number 483 out of 5465 computations...
# Parameter updates using loss computation number 484 out of 5465 computations...
# Parameter updates using loss computation number 485 out of 5465 computations...
# Parameter updates using loss computation number 486 out of 5465 computations...
# Parameter updates using loss computation number 487 out of 5465 computations...
# Parameter updates using loss computation number 488 out of 5465 computations...
# Parameter updates using loss computation number 489 out of 5465 computations...
# Parameter updates using loss computation number 490 out of 5465 computations...
# Parameter updates using loss computation number 491 out of 5465 computations...
# Parameter updates using loss computation number 492 out of 5465 computations...
# Parameter updates using loss computation number 493 out of 5465 computations...
# Parameter updates using loss computation number 494 out of 5465 computations...
# Parameter updates using loss computation number 495 out of 5465 computations...
# Parameter updates using loss computation number 496 out of 5465 computations...
# Parameter updates using loss computation number 497 out of 5465 computations...
# Parameter updates using loss computation number 498 out of 5465 computations...
# Parameter updates using loss computation number 499 out of 5465 computations...
# Parameter updates using loss computation number 500 out of 5465 computations...
# Parameter updates using loss computation number 501 out of 5465 computations...
# Parameter updates using loss computation number 502 out of 5465 computations...
# Parameter updates using loss computation number 503 out of 5465 computations...
# Parameter updates using loss computation number 504 out of 5465 computations...
# Parameter updates using loss computation number 505 out of 5465 computations...
# Parameter updates using loss computation number 506 out of 5465 computations...
# Parameter updates using loss computation number 507 out of 5465 computations...
# Parameter updates using loss computation number 508 out of 5465 computations...
# Parameter updates using loss computation number 509 out of 5465 computations...
# Parameter updates using loss computation number 510 out of 5465 computations...
# Parameter updates using loss computation number 511 out of 5465 computations...
# Parameter updates using loss computation number 512 out of 5465 computations...
# Parameter updates using loss computation number 513 out of 5465 computations...
# Parameter updates using loss computation number 514 out of 5465 computations...
# Parameter updates using loss computation number 515 out of 5465 computations...
# Parameter updates using loss computation number 516 out of 5465 computations...
# Parameter updates using loss computation number 517 out of 5465 computations...
# Parameter updates using loss computation number 518 out of 5465 computations...
# Parameter updates using loss computation number 519 out of 5465 computations...
# Parameter updates using loss computation number 520 out of 5465 computations...
# Parameter updates using loss computation number 521 out of 5465 computations...
# Parameter updates using loss computation number 522 out of 5465 computations...
# Parameter updates using loss computation number 523 out of 5465 computations...
# Parameter updates using loss computation number 524 out of 5465 computations...
# Parameter updates using loss computation number 525 out of 5465 computations...
# Parameter updates using loss computation number 526 out of 5465 computations...
# Parameter updates using loss computation number 527 out of 5465 computations...
# Parameter updates using loss computation number 528 out of 5465 computations...
# Parameter updates using loss computation number 529 out of 5465 computations...
# Parameter updates using loss computation number 530 out of 5465 computations...
# Parameter updates using loss computation number 531 out of 5465 computations...
# Parameter updates using loss computation number 532 out of 5465 computations...
# Parameter updates using loss computation number 533 out of 5465 computations...
# Parameter updates using loss computation number 534 out of 5465 computations...
# Parameter updates using loss computation number 535 out of 5465 computations...
# Parameter updates using loss computation number 536 out of 5465 computations...
# Parameter updates using loss computation number 537 out of 5465 computations...
# Parameter updates using loss computation number 538 out of 5465 computations...
# Parameter updates using loss computation number 539 out of 5465 computations...
# Parameter updates using loss computation number 540 out of 5465 computations...
# Parameter updates using loss computation number 541 out of 5465 computations...
# Parameter updates using loss computation number 542 out of 5465 computations...
# Parameter updates using loss computation number 543 out of 5465 computations...
# Parameter updates using loss computation number 544 out of 5465 computations...
# Parameter updates using loss computation number 545 out of 5465 computations...
# Parameter updates using loss computation number 546 out of 5465 computations...
# Parameter updates using loss computation number 547 out of 5465 computations...
# Parameter updates using loss computation number 548 out of 5465 computations...
# Parameter updates using loss computation number 549 out of 5465 computations...
# Parameter updates using loss computation number 550 out of 5465 computations...
# Parameter updates using loss computation number 551 out of 5465 computations...
# Parameter updates using loss computation number 552 out of 5465 computations...
# Parameter updates using loss computation number 553 out of 5465 computations...
# Parameter updates using loss computation number 554 out of 5465 computations...
# Parameter updates using loss computation number 555 out of 5465 computations...
# Parameter updates using loss computation number 556 out of 5465 computations...
# Parameter updates using loss computation number 557 out of 5465 computations...
# Parameter updates using loss computation number 558 out of 5465 computations...
# Parameter updates using loss computation number 559 out of 5465 computations...
# Parameter updates using loss computation number 560 out of 5465 computations...
# Parameter updates using loss computation number 561 out of 5465 computations...
# Parameter updates using loss computation number 562 out of 5465 computations...
# Parameter updates using loss computation number 563 out of 5465 computations...
# Parameter updates using loss computation number 564 out of 5465 computations...
# Parameter updates using loss computation number 565 out of 5465 computations...
# Parameter updates using loss computation number 566 out of 5465 computations...
# Parameter updates using loss computation number 567 out of 5465 computations...
# Parameter updates using loss computation number 568 out of 5465 computations...
# Parameter updates using loss computation number 569 out of 5465 computations...
# Parameter updates using loss computation number 570 out of 5465 computations...
# Parameter updates using loss computation number 571 out of 5465 computations...
# Parameter updates using loss computation number 572 out of 5465 computations...
# Parameter updates using loss computation number 573 out of 5465 computations...
# Parameter updates using loss computation number 574 out of 5465 computations...
# Parameter updates using loss computation number 575 out of 5465 computations...
# Parameter updates using loss computation number 576 out of 5465 computations...
# Parameter updates using loss computation number 577 out of 5465 computations...
# Parameter updates using loss computation number 578 out of 5465 computations...
# Parameter updates using loss computation number 579 out of 5465 computations...
# Parameter updates using loss computation number 580 out of 5465 computations...
# Parameter updates using loss computation number 581 out of 5465 computations...
# Parameter updates using loss computation number 582 out of 5465 computations...
# Parameter updates using loss computation number 583 out of 5465 computations...
# Parameter updates using loss computation number 584 out of 5465 computations...
# Parameter updates using loss computation number 585 out of 5465 computations...
# Parameter updates using loss computation number 586 out of 5465 computations...
# Parameter updates using loss computation number 587 out of 5465 computations...
# Parameter updates using loss computation number 588 out of 5465 computations...
# Parameter updates using loss computation number 589 out of 5465 computations...
# Parameter updates using loss computation number 590 out of 5465 computations...
# Parameter updates using loss computation number 591 out of 5465 computations...
# Parameter updates using loss computation number 592 out of 5465 computations...
# Parameter updates using loss computation number 593 out of 5465 computations...
# Parameter updates using loss computation number 594 out of 5465 computations...
# Parameter updates using loss computation number 595 out of 5465 computations...
# Parameter updates using loss computation number 596 out of 5465 computations...
# Parameter updates using loss computation number 597 out of 5465 computations...
# Parameter updates using loss computation number 598 out of 5465 computations...
# Parameter updates using loss computation number 599 out of 5465 computations...
# Parameter updates using loss computation number 600 out of 5465 computations...
# Parameter updates using loss computation number 601 out of 5465 computations...
# ...
# Parameter updates using loss computation number 5269 out of 5465 computations...
# Parameter updates using loss computation number 5270 out of 5465 computations...
# Parameter updates using loss computation number 5271 out of 5465 computations...
# Parameter updates using loss computation number 5272 out of 5465 computations...
# Parameter updates using loss computation number 5273 out of 5465 computations...
# Parameter updates using loss computation number 5274 out of 5465 computations...
# Parameter updates using loss computation number 5275 out of 5465 computations...
# Parameter updates using loss computation number 5276 out of 5465 computations...
# Parameter updates using loss computation number 5277 out of 5465 computations...
# Parameter updates using loss computation number 5278 out of 5465 computations...
# Parameter updates using loss computation number 5279 out of 5465 computations...
# Parameter updates using loss computation number 5280 out of 5465 computations...
# Parameter updates using loss computation number 5281 out of 5465 computations...
# Parameter updates using loss computation number 5282 out of 5465 computations...
# Parameter updates using loss computation number 5283 out of 5465 computations...
# Parameter updates using loss computation number 5284 out of 5465 computations...
# Parameter updates using loss computation number 5285 out of 5465 computations...
# Parameter updates using loss computation number 5286 out of 5465 computations...
# Parameter updates using loss computation number 5287 out of 5465 computations...
# Parameter updates using loss computation number 5288 out of 5465 computations...
# Parameter updates using loss computation number 5289 out of 5465 computations...
# Parameter updates using loss computation number 5290 out of 5465 computations...
# Parameter updates using loss computation number 5291 out of 5465 computations...
# Parameter updates using loss computation number 5292 out of 5465 computations...
# Parameter updates using loss computation number 5293 out of 5465 computations...
# Parameter updates using loss computation number 5294 out of 5465 computations...
# Parameter updates using loss computation number 5295 out of 5465 computations...
# Parameter updates using loss computation number 5296 out of 5465 computations...
# Parameter updates using loss computation number 5297 out of 5465 computations...
# Parameter updates using loss computation number 5298 out of 5465 computations...
# Parameter updates using loss computation number 5299 out of 5465 computations...
# Parameter updates using loss computation number 5300 out of 5465 computations...
# Parameter updates using loss computation number 5301 out of 5465 computations...
# Parameter updates using loss computation number 5302 out of 5465 computations...
# Parameter updates using loss computation number 5303 out of 5465 computations...
# Parameter updates using loss computation number 5304 out of 5465 computations...
# Parameter updates using loss computation number 5305 out of 5465 computations...
# Parameter updates using loss computation number 5306 out of 5465 computations...
# Parameter updates using loss computation number 5307 out of 5465 computations...
# Parameter updates using loss computation number 5308 out of 5465 computations...
# Parameter updates using loss computation number 5309 out of 5465 computations...
# Parameter updates using loss computation number 5310 out of 5465 computations...
# Parameter updates using loss computation number 5311 out of 5465 computations...
# Parameter updates using loss computation number 5312 out of 5465 computations...
# Parameter updates using loss computation number 5313 out of 5465 computations...
# Parameter updates using loss computation number 5314 out of 5465 computations...
# Parameter updates using loss computation number 5315 out of 5465 computations...
# Parameter updates using loss computation number 5316 out of 5465 computations...
# Parameter updates using loss computation number 5317 out of 5465 computations...
# Parameter updates using loss computation number 5318 out of 5465 computations...
# Parameter updates using loss computation number 5319 out of 5465 computations...
# Parameter updates using loss computation number 5320 out of 5465 computations...
# Parameter updates using loss computation number 5321 out of 5465 computations...
# Parameter updates using loss computation number 5322 out of 5465 computations...
# Parameter updates using loss computation number 5323 out of 5465 computations...
# Parameter updates using loss computation number 5324 out of 5465 computations...
# Parameter updates using loss computation number 5325 out of 5465 computations...
# Parameter updates using loss computation number 5326 out of 5465 computations...
# Parameter updates using loss computation number 5327 out of 5465 computations...
# Parameter updates using loss computation number 5328 out of 5465 computations...
# Parameter updates using loss computation number 5329 out of 5465 computations...
# Parameter updates using loss computation number 5330 out of 5465 computations...
# Parameter updates using loss computation number 5331 out of 5465 computations...
# Parameter updates using loss computation number 5332 out of 5465 computations...
# Parameter updates using loss computation number 5333 out of 5465 computations...
# Parameter updates using loss computation number 5334 out of 5465 computations...
# Parameter updates using loss computation number 5335 out of 5465 computations...
# Parameter updates using loss computation number 5336 out of 5465 computations...
# Parameter updates using loss computation number 5337 out of 5465 computations...
# Parameter updates using loss computation number 5338 out of 5465 computations...
# Parameter updates using loss computation number 5339 out of 5465 computations...
# Parameter updates using loss computation number 5340 out of 5465 computations...
# Parameter updates using loss computation number 5341 out of 5465 computations...
# Parameter updates using loss computation number 5342 out of 5465 computations...
# Parameter updates using loss computation number 5343 out of 5465 computations...
# Parameter updates using loss computation number 5344 out of 5465 computations...
# Parameter updates using loss computation number 5345 out of 5465 computations...
# Parameter updates using loss computation number 5346 out of 5465 computations...
# Parameter updates using loss computation number 5347 out of 5465 computations...
# Parameter updates using loss computation number 5348 out of 5465 computations...
# Parameter updates using loss computation number 5349 out of 5465 computations...
# Parameter updates using loss computation number 5350 out of 5465 computations...
# Parameter updates using loss computation number 5351 out of 5465 computations...
# Parameter updates using loss computation number 5352 out of 5465 computations...
# Parameter updates using loss computation number 5353 out of 5465 computations...
# Parameter updates using loss computation number 5354 out of 5465 computations...
# Parameter updates using loss computation number 5355 out of 5465 computations...
# Parameter updates using loss computation number 5356 out of 5465 computations...
# Parameter updates using loss computation number 5357 out of 5465 computations...
# Parameter updates using loss computation number 5358 out of 5465 computations...
# Parameter updates using loss computation number 5359 out of 5465 computations...
# Parameter updates using loss computation number 5360 out of 5465 computations...
# Parameter updates using loss computation number 5361 out of 5465 computations...
# Parameter updates using loss computation number 5362 out of 5465 computations...
# Parameter updates using loss computation number 5363 out of 5465 computations...
# Parameter updates using loss computation number 5364 out of 5465 computations...
# Parameter updates using loss computation number 5365 out of 5465 computations...
# Parameter updates using loss computation number 5366 out of 5465 computations...
# Parameter updates using loss computation number 5367 out of 5465 computations...
# Parameter updates using loss computation number 5368 out of 5465 computations...
# Parameter updates using loss computation number 5369 out of 5465 computations...
# Parameter updates using loss computation number 5370 out of 5465 computations...
# Parameter updates using loss computation number 5371 out of 5465 computations...
# Parameter updates using loss computation number 5372 out of 5465 computations...
# Parameter updates using loss computation number 5373 out of 5465 computations...
# Parameter updates using loss computation number 5374 out of 5465 computations...
# Parameter updates using loss computation number 5375 out of 5465 computations...
# Parameter updates using loss computation number 5376 out of 5465 computations...
# Parameter updates using loss computation number 5377 out of 5465 computations...
# Parameter updates using loss computation number 5378 out of 5465 computations...
# Parameter updates using loss computation number 5379 out of 5465 computations...
# Parameter updates using loss computation number 5380 out of 5465 computations...
# Parameter updates using loss computation number 5381 out of 5465 computations...
# Parameter updates using loss computation number 5382 out of 5465 computations...
# Parameter updates using loss computation number 5383 out of 5465 computations...
# Parameter updates using loss computation number 5384 out of 5465 computations...
# Parameter updates using loss computation number 5385 out of 5465 computations...
# Parameter updates using loss computation number 5386 out of 5465 computations...
# Parameter updates using loss computation number 5387 out of 5465 computations...
# Parameter updates using loss computation number 5388 out of 5465 computations...
# Parameter updates using loss computation number 5389 out of 5465 computations...
# Parameter updates using loss computation number 5390 out of 5465 computations...
# Parameter updates using loss computation number 5391 out of 5465 computations...
# Parameter updates using loss computation number 5392 out of 5465 computations...
# Parameter updates using loss computation number 5393 out of 5465 computations...
# Parameter updates using loss computation number 5394 out of 5465 computations...
# Parameter updates using loss computation number 5395 out of 5465 computations...
# Parameter updates using loss computation number 5396 out of 5465 computations...
# Parameter updates using loss computation number 5397 out of 5465 computations...
# Parameter updates using loss computation number 5398 out of 5465 computations...
# Parameter updates using loss computation number 5399 out of 5465 computations...
# Parameter updates using loss computation number 5400 out of 5465 computations...
# Parameter updates using loss computation number 5401 out of 5465 computations...
# Parameter updates using loss computation number 5402 out of 5465 computations...
# Parameter updates using loss computation number 5403 out of 5465 computations...
# Parameter updates using loss computation number 5404 out of 5465 computations...
# Parameter updates using loss computation number 5405 out of 5465 computations...
# Parameter updates using loss computation number 5406 out of 5465 computations...
# Parameter updates using loss computation number 5407 out of 5465 computations...
# Parameter updates using loss computation number 5408 out of 5465 computations...
# Parameter updates using loss computation number 5409 out of 5465 computations...
# Parameter updates using loss computation number 5410 out of 5465 computations...
# Parameter updates using loss computation number 5411 out of 5465 computations...
# Parameter updates using loss computation number 5412 out of 5465 computations...
# Parameter updates using loss computation number 5413 out of 5465 computations...
# Parameter updates using loss computation number 5414 out of 5465 computations...
# Parameter updates using loss computation number 5415 out of 5465 computations...
# Parameter updates using loss computation number 5416 out of 5465 computations...
# Parameter updates using loss computation number 5417 out of 5465 computations...
# Parameter updates using loss computation number 5418 out of 5465 computations...
# Parameter updates using loss computation number 5419 out of 5465 computations...
# Parameter updates using loss computation number 5420 out of 5465 computations...
# Parameter updates using loss computation number 5421 out of 5465 computations...
# Parameter updates using loss computation number 5422 out of 5465 computations...
# Parameter updates using loss computation number 5423 out of 5465 computations...
# Parameter updates using loss computation number 5424 out of 5465 computations...
# Parameter updates using loss computation number 5425 out of 5465 computations...
# Parameter updates using loss computation number 5426 out of 5465 computations...
# Parameter updates using loss computation number 5427 out of 5465 computations...
# Parameter updates using loss computation number 5428 out of 5465 computations...
# Parameter updates using loss computation number 5429 out of 5465 computations...
# Parameter updates using loss computation number 5430 out of 5465 computations...
# Parameter updates using loss computation number 5431 out of 5465 computations...
# Parameter updates using loss computation number 5432 out of 5465 computations...
# Parameter updates using loss computation number 5433 out of 5465 computations...
# Parameter updates using loss computation number 5434 out of 5465 computations...
# Parameter updates using loss computation number 5435 out of 5465 computations...
# Parameter updates using loss computation number 5436 out of 5465 computations...
# Parameter updates using loss computation number 5437 out of 5465 computations...
# Parameter updates using loss computation number 5438 out of 5465 computations...
# Parameter updates using loss computation number 5439 out of 5465 computations...
# Parameter updates using loss computation number 5440 out of 5465 computations...
# Parameter updates using loss computation number 5441 out of 5465 computations...
# Parameter updates using loss computation number 5442 out of 5465 computations...
# Parameter updates using loss computation number 5443 out of 5465 computations...
# Parameter updates using loss computation number 5444 out of 5465 computations...
# Parameter updates using loss computation number 5445 out of 5465 computations...
# Parameter updates using loss computation number 5446 out of 5465 computations...
# Parameter updates using loss computation number 5447 out of 5465 computations...
# Parameter updates using loss computation number 5448 out of 5465 computations...
# Parameter updates using loss computation number 5449 out of 5465 computations...
# Parameter updates using loss computation number 5450 out of 5465 computations...
# Parameter updates using loss computation number 5451 out of 5465 computations...
# Parameter updates using loss computation number 5452 out of 5465 computations...
# Parameter updates using loss computation number 5453 out of 5465 computations...
# Parameter updates using loss computation number 5454 out of 5465 computations...
# Parameter updates using loss computation number 5455 out of 5465 computations...
# Parameter updates using loss computation number 5456 out of 5465 computations...
# Parameter updates using loss computation number 5457 out of 5465 computations...
# Parameter updates using loss computation number 5458 out of 5465 computations...
# Parameter updates using loss computation number 5459 out of 5465 computations...
# Parameter updates using loss computation number 5460 out of 5465 computations...
# Parameter updates using loss computation number 5461 out of 5465 computations...
# Parameter updates using loss computation number 5462 out of 5465 computations...
# Parameter updates using loss computation number 5463 out of 5465 computations...
# Parameter updates using loss computation number 5464 out of 5465 computations...
# Parameter updates using loss computation number 5465 out of 5465 computations...

# %% [markdown]
# # Part 3 - Generating Images
# In this section, we will generate some new images using the generator component of the GAN.

# %%
# Choose a number of new images to generate
n_new = 25

# %%
# Generate some new images using the generator
noise = tf.random.normal([n_new, latent_dim])
generated_images = generator(noise, training = False)

# Rescale the image gray levels to [0, 1]
generated_images = 0.5 * generated_images + 0.5

plt.figure(figsize = (5, 5))

for i in range(n_new):
    plt.subplot(int(np.sqrt(n_new)), int(np.sqrt(n_new)), i + 1)
    plt.imshow(generated_images[i, :, :, 0], cmap = 'gray')

plt.axis('off')
plt.show()
